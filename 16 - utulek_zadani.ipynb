# %% [markdown]
# # 1
# Vytvořte třídu Utulek, který bude obsahovat tyto vlastnosti:
#
# *   Název
# *   Maximální kapacita
# *   SeznamZvířat
#
# A jeho metody budou:
#
# *  getNazev
# *  getMaxKapacita
# *  getSeznamZvirat
# *  setNazev
# *  setMaxKapacita
# *  pridatZvire
# *  odeberZvire
# *  ToString

# %%
class Utulek:
    def __init__(self, nazev, kapacita, zvirata=None):
        self.nazev = nazev
        self.kapacita = kapacita
        if zvirata is None:
            self.zvirata = [] if zvirata is None else zvirata
    def pridej_zvire(self, zvire):
        if len(self.zvirata) < self.kapacita:
            if zvire in self.zvirata:
                print(f"{zvire} je již v útulku")
            else:
                self.zvirata.append(zvire)
                print(f"{zvire} byl přidán do útulku")
        else:
            print("Útulek je plný!")

    def odeber_zvire(self, zvire):
        if zvire in self.zvirata:
            self.zvirata.remove(zvire)
            print("Zvire bylo odebráno")
        else:
            print("Zvíře v útulku není")

    def __str__(self):
        return f"Utulek {self.nazev} s kapacitou {self.kapacita}"
    




zv1 = "Jezevec"
Utulek_bez_zvirat = Utulek("Happy Paws" , 5)
Utulek_s_zviraty = Utulek("Animal Haven", 3, [zv1,"Kocka"])
Utulek_s_zviraty.pridej_zvire("Kocka")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 34
#      32 Utulek_bez_zvirat = Utulek("Happy Paws" , 5)
#      33 Utulek_s_zviraty = Utulek("Animal Haven", 3, [zv1,"Kocka"])
# ---> 34 Utulek_s_zviraty.pridej_zvire("Kocka")
#
# Cell In[7], line 8, in Utulek.pridej_zvire(self, zvire)
#       7 def pridej_zvire(self, zvire):
# ----> 8     if len(self.zvirata) < self.kapacita:
#       9         if zvire in self.zvirata:
#      10             print(f"{zvire} je již v útulku")
#
# AttributeError: 'Utulek' object has no attribute 'zvirata'

# %% [markdown]
# Použijte třídu útulek a nějaký útulek založte. Přidejte do něj větší počet zvířat než je kapacita, a odeberte jedno zvíře

# %%
#TODO

# %% [markdown]
# # 2
# Vytvořte třídu Zvire, která bude obsahovat tyto vlasnosti
# * Jméno
# * Hmotnost
#
# a metody budou pro get a set a ToString a metodu zarvi()

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 class Pes(Zvire):
#       2     def __init__(self, jmeno, hmotnost, hlasitost):
#       3         Zvire.__init__(self, jmeno, hmotnost)
#
# NameError: name 'Zvire' is not defined

# %% [markdown]
# # 3
# Vytvořte dvě třídy Kocka, Pes, které budou dědit od třídy Zvire a přepište metodu zařvi, aby odpovídala psu nebo kočce

# %%
#TODO Pes

# %%
#TODO Kocka

# %% [markdown]
# # 4
# Přepiště třídu Utulek, aby přijímala jako vstup Třídy Zvíře

# %% [markdown]
# #4
# Použijte všechny třídy a do vytvořeného útulku přidejte nějaká zvířata. Ošetřete přeplněnou kapacitu útulku.

# %%
#TODO
